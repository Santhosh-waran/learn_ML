# %%
import pandas as pd

# %%
data = pd.read_csv("pokeman_data.csv")

# %%
data.head(5)
data = data.drop(columns="Unnamed: 0")

# %%
data['Total'] = data.iloc[:,5:11].sum(axis=1)

# %%
data.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    274
# 1       80     60           1      False    346
# 2      100     80           1      False    446
# 3      120     80           1      False    546
# 4       50     65           1      False    271

# %%
45+49+49+65+65+45
# Out:
# 318

# %%
# data.to_csv("pokeman_data.csv")

# %%
new_data = data.loc[(data["Type 1"] == 'Grass') & (data['Type 2'] == 'Poison')] 
new_data.reset_index()
new_data.to_csv("Grass_Poison.csv")
new_data
new_data.loc[~new_data['Name'].str.contains('saur')]
# Out:
#        #        Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 48    43      Oddish  Grass  Poison   45      50       55       75       65
# 49    44       Gloom  Grass  Poison   60      65       70       85       75
# 50    45   Vileplume  Grass  Poison   75      80       85      110       90
# 75    69  Bellsprout  Grass  Poison   50      75       35       70       30
# 76    70  Weepinbell  Grass  Poison   65      90       50       85       45
# 77    71  Victreebel  Grass  Poison   80     105       65      100       70
# 344  315     Roselia  Grass  Poison   50      60       45      100       80
# 451  406       Budew  Grass  Poison   40      30       35       50       70
# 452  407    Roserade  Grass  Poison   60      70       65      125      105
# 651  590     Foongus  Grass  Poison   69      55       45       55       55
# 652  591   Amoonguss  Grass  Poison  114      85       70       85       80
#
#      Speed  Generation  Legendary  Total
# ...

# %%
# data.loc[data["Total"] > 500 , ["Generation","Legendary"]]  = ["Test_v 1","Test_v 2"]

data = pd.read_csv("pokeman_data.csv")

# %%
data["count"] = 1
data.groupby('Generation').count()
# Out:
#               #  Name  Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Generation
# 1           166   166     166      78  166     166      166      166      166
# 2           106   106     106      55  106     106      106      106      106
# 3           160   160     160      82  160     160      160      160      160
# 4           121   121     121      67  121     121      121      121      121
# 5           165   165     165      82  165     165      165      165      165
# 6            82    82      82      50   82      82       82       82       82
#
#             Speed  Legendary  Total  count
# Generation
# 1             166        166    166    166
# 2             106        106    106    106
# 3             160        160    160    160
# 4             121        121    121    121
# 5             165        165    165    165
# 6              82         82     82     82
